# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\cleme\laboratorios\PROYECTO-SHARKS-CARLOS\data\attacks.csv', encoding= "ISO-8859-1")

# %%
pd.options.display.max_columns = None

# %%
df.head(5)
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
# ...

# %%
df.shape
# Out:
# (25723, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %% [markdown]
#   1 Paso.- Consiste en filtrar todas las filas que contengan un número de celdas sin información en un número de 8 o más y eliminarlas considerando que la tabla tiene 23 columnas.

# %%
df = df[df.count(axis=1) >= 8]

# %%
df.shape
# Out:
# (6302, 24)

# %% [markdown]
# 2 Paso. Rellenar todas las celdas sin datos con 'unknow', considerando como 8 celdas en la fila la menor información posible para ser interpretable.

# %%
df = df.fillna('unknown') # rellenar todas las casillas nulas con unknow a fin de limpiar los nulos.

# %%
print(df.head(20))
# Out:
#      Case Number                  Date    Year          Type       Country  \
# 0     2018.06.25           25-Jun-2018  2018.0       Boating           USA
# 1     2018.06.18           18-Jun-2018  2018.0    Unprovoked           USA
# 2     2018.06.09           09-Jun-2018  2018.0       Invalid           USA
# 3     2018.06.08           08-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 4     2018.06.04           04-Jun-2018  2018.0      Provoked        MEXICO
# 5   2018.06.03.b           03-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 6   2018.06.03.a           03-Jun-2018  2018.0    Unprovoked        BRAZIL
# 7     2018.05.27           27-May-2018  2018.0    Unprovoked           USA
# 8   2018.05.26.b           26-May-2018  2018.0    Unprovoked           USA
# 9   2018.05.26.a           26-May-2018  2018.0    Unprovoked           USA
# 10    2018.05.24           24-May-2018  2018.0      Provoked     AUSTRALIA
# ...

# %% [markdown]
# 3 paso Elimino la fila de año para rellenarla con el índice de 1 a n registros, en definitiva se denomina "Case number". Ejecuto un bucle  que me cambia esta columna de forma inversa del 1 en la última posición hasta el primero en la posición 6302

# %%
n_fila = df.shape[0] #cambio la lista de sentido, de abajo a arriba.

for i in range(n_fila):
    df.loc[i, 'Case Number'] = n_fila - i


display(df.head(5))
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0        6302  25-Jun-2018  2018.0     Boating        USA       California
# 1        6301  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2        6300  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3        6299  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4        6298  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex       Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F       57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F       11
# 2                    Habush, Oahu      Surfing      John Denges    M       48
# 3              Arrawarra Headland      Surfing             male    M  unknown
# 4                        La Ticla  Free diving   Gustavo Ramos     M  unknown
#
# ...

# %% [markdown]
# 4 paso Cambio la columna year a integer, para ello, busco celdas q no sean float y encuentro 2 unknow, las cambio y ejecuto y el resultado es el año sin comas.

# %%
resultados = df[df['Year'] == 'unknown'] #localizo unknow.
resultados
# Out:
#      Case Number                  Date     Year        Type    Country  \
# 187         6115  Reported 08-Jan-2017  unknown     Invalid  AUSTRALIA
# 6079         223  Reported 19-Aug-1836  unknown  Unprovoked    ENGLAND
#
#             Area    Location      Activity          Name Sex       Age  \
# 187   Queensland     unknown  Spearfishing  Kerry Daniel    M       35
# 6079  Cumberland  Whitehaven      Swimming         a boy    M  unknown
#
#                                       Injury Fatal (Y/N)     Time    Species   \
# 187   No attack, shark made a threat display     unknown  unknown  Bull shark
# 6079                                   FATAL           Y  unknown     unknown
#
#       Investigator or Source                           pdf  \
# 187   Liquid Vision 1/8/2017  2017.01.08.R-KerryDaniel.pdf
# 6079          C. Moore, GSAF   1835.08.19.R-Whitehaven.pdf
#
#                                                                             href formula  \
# ...

# %%
df.loc[187,'Year'] = 2017 #cambio al el valor

# %%
df.loc[6079,'Year'] = 1836 #cambio a 0 el valor

# %%
df [df.Year == 'unknown']
# Out:
# Empty DataFrame
# Columns: [Case Number, Date, Year, Type, Country, Area, Location, Activity, Name, Sex , Age, Injury, Fatal (Y/N), Time, Species , Investigator or Source, pdf, href formula, href, Case Number.1, Case Number.2, original order, Unnamed: 22, Unnamed: 23]
# Index: []

# %%
df['Year'] = df['Year'].astype(int) # paso el type de la columna Year a integer

# %%
display(df.head())  # el retorno es sin coma en 'Year'
# Out:
#   Case Number         Date  Year        Type    Country             Area  \
# 0        6302  25-Jun-2018  2018     Boating        USA       California
# 1        6301  18-Jun-2018  2018  Unprovoked        USA          Georgia
# 2        6300  09-Jun-2018  2018     Invalid        USA           Hawaii
# 3        6299  08-Jun-2018  2018  Unprovoked  AUSTRALIA  New South Wales
# 4        6298  04-Jun-2018  2018    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex       Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F       57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F       11
# 2                    Habush, Oahu      Surfing      John Denges    M       48
# 3              Arrawarra Headland      Surfing             male    M  unknown
# 4                        La Ticla  Free diving   Gustavo Ramos     M  unknown
#
# ...

# %% [markdown]
# paso 5. Cambio los valores de la columna género a m y f

# %%
print(df['Sex '].value_counts()) # reviso cuantos tipos de genero hay, para ello muestro las denominaciones de valores que hay en la columna
# Out:
# M          5094
# F           637
# unknown     565
# M             2
# N             2
# lli           1
# .             1
# Name: Sex , dtype: int64

# %%
resultados_1= df[df['Sex '] == '.'] #Investigo que hay en las columnas, si contienen información valiosa
resultados_1
# Out:
#      Case Number                  Date  Year          Type           Country  \
# 5437         865  Reported 02-Jun-1908  1908  Sea Disaster  PAPUA NEW GUINEA
#
#              Area Location Activity     Name Sex       Age  \
# 5437  New Britain   Matupi        .  unknown    .  unknown
#
#                                                                                           Injury  \
# 5437  Remains of 3 humans recovered from shark, but shark involvement prior to death unconfirmed
#
#      Fatal (Y/N)     Time                   Species   \
# 5437           Y  unknown  Allegedly a 33-foot shark
#
#          Investigator or Source                      pdf  \
# 5437  Taranaki Herald, 6/2/1908  1908.06.02.R-Matupi.pdf
#
#                                                                        href formula  \
# 5437  http://sharkattackfile.net/spreadsheets/pdf_directory/1908.06.02.R-Matupi.pdf
#
#                                                                                href  \
# ...

# %%
resultados_1= df[df['Sex '] == 'lli']
resultados_1
# Out:
#      Case Number         Date  Year        Type Country        Area  \
# 1624        4678  11-Nov-2004  2004  Unprovoked     USA  California
#
#                                             Location Activity        Name  \
# 1624  Bunkers, Humboldt Bay, Eureka, Humboldt County  Surfing  Brian Kang
#
#      Sex  Age                              Injury Fatal (Y/N)   Time  \
# 1624  lli  38  Lacerations to hand, knee & thigh            N  13h30
#
#                      Species             Investigator or Source  \
# 1624  5.5 m [18'] white shark  R. Collier, GSAF
#
#                         pdf  \
# 1624  2004.11.11.b-Kang.pdf
#
#                                                                      href formula  \
# 1624  http://sharkattackfile.net/spreadsheets/pdf_directory/2004.11.11.b-Kang.pdf
#
#                                                                              href  \
# 1624  http://sharkattackfile.net/spreadsheets/pdf_directory/2004.11.11.b-Kang.pdf
#
# ...

# %%
resultados_1= df[df['Sex '] == 'N']
resultados_1
# Out:
#      Case Number                  Date  Year      Type    Country  \
# 4938        1364           11-Jul-1934  1934   Boating  AUSTRALIA
# 6131         171  Reported 18-Dec-1801  1801  Provoked    unknown
#
#                  Area  Location                         Activity  \
# 4938  New South Wales  Cronulla                          Fishing
# 6131          unknown   unknown  Standing on landed shark's tail
#
#                                              Name Sex       Age  \
# 4938  18' boat, occupants William & Leslie Newton    N  unknown
# 6131                             Stephen Pettigew    N  unknown
#
#                                                                                           Injury  \
# 4938  No injury to occupants Sharks continually followed the dinghy, and one smashed its rudder
# 6131                                                                    FATAL, PROVOKED INCIDENT
#
#      Fatal (Y/N)     Time            Species   \
# ...

# %%
df['Sex '].replace(['lli'], ['M'], inplace=True) #reemplazo 'lli' por 'M'

# %%
df['Sex '].replace(['.'], ['unknown'], inplace=True) #reemplazo '.' por 'unknow'

# %%
df['Sex '].replace(['N'], ['unknown'], inplace=True) #reemplazo 'N' por 'M'

# %%
df['Sex '].replace(['M '], ['M'], inplace=True)

# %%
print(df['Sex '].value_counts()) # compruebo que me queda limpia con sólo 3 valores
# Out:
# M          5097
# F           637
# unknown     568
# Name: Sex , dtype: int64

# %% [markdown]
# paso 6 Exploro columnas iguales y les cambio el nombre, elimino los resultados de las columnas, si están repetidos o los renombro

# %%
df = df.rename(columns={'href': 'Unvalid3'}) #nuevo nombre de columna

# %%
df['Unvalid3'] = 'See_href_formula' #Cambio los valores por repetidos
print(df['Unvalid3'].value_counts())
# Out:
# See_href_formula    6302
# Name: Unvalid3, dtype: int64

# %%
df = df.rename(columns={'Case Number.1': 'Empty1'})#nuevo nombre de columna

# %%
df['Empty1'] = 'no_values' #Cambio los valores por repetidos con Date
print(df['Empty1'].value_counts())
# Out:
# no_values    6302
# Name: Empty1, dtype: int64

# %%
df = df.rename(columns={'Case Number.2': 'Empty2'})#nuevo nombre de columna

# %%
df['Empty2'] = 'no_values' #Cambio los valores por repetidos con Date
print(df['Empty2'].value_counts())
# Out:
# no_values    6302
# Name: Empty2, dtype: int64

# %%
df['original order'] = df['original order'].astype(str) #cambio de float a string

# %%
df = df.rename(columns={'original order': 'Empty3'})#nuevo nombre de columna

# %%
df['Empty3'] = 'no_values' #Cambio los valores por repetidos con Case number
print(df['Empty3'].value_counts())
# Out:
# no_values    6302
# Name: Empty3, dtype: int64

# %%
df.head()
# Out:
#   Case Number         Date  Year        Type    Country             Area  \
# 0        6302  25-Jun-2018  2018     Boating        USA       California
# 1        6301  18-Jun-2018  2018  Unprovoked        USA          Georgia
# 2        6300  09-Jun-2018  2018     Invalid        USA           Hawaii
# 3        6299  08-Jun-2018  2018  Unprovoked  AUSTRALIA  New South Wales
# 4        6298  04-Jun-2018  2018    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex       Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F       57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F       11
# 2                    Habush, Oahu      Surfing      John Denges    M       48
# 3              Arrawarra Headland      Surfing             male    M  unknown
# 4                        La Ticla  Free diving   Gustavo Ramos     M  unknown
#
# ...

# %% [markdown]
# Paso 7 Cambiar tipo columna 'Date' a datetime para su correcto manejo futuro

# %%
tipo_columna = df['Date'].dtype # Verifico el tipo object
print(tipo_columna)
# Out:
# object

# %%
from datetime import date #importo librerias
from datetime import datetime

# %%
df['Date'] = pd.to_datetime(df['Date'],errors='coerce') #cambio de un tipo a otro
df.head()
# Out:
#   Case Number       Date  Year        Type    Country             Area  \
# 0        6302 2018-06-25  2018     Boating        USA       California
# 1        6301 2018-06-18  2018  Unprovoked        USA          Georgia
# 2        6300 2018-06-09  2018     Invalid        USA           Hawaii
# 3        6299 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4        6298 2018-06-04  2018    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex       Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F       57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F       11
# 2                    Habush, Oahu      Surfing      John Denges    M       48
# 3              Arrawarra Headland      Surfing             male    M  unknown
# 4                        La Ticla  Free diving   Gustavo Ramos     M  unknown
#
# ...

# %% [markdown]
# paso 8 Agrupo valores en Y,N, unknown. quito valores no válidos para busqueda

# %%
print(df['Fatal (Y/N)'].value_counts())
# Out:
# N          4293
# Y          1388
# unknown     539
# UNKNOWN      71
#  N            7
# M             1
# 2017          1
# N             1
# y             1
# Name: Fatal (Y/N), dtype: int64

# %%
df['Fatal (Y/N)'].replace(['UNKNOWN','2017', 'M'], ['unknown', 'unknown', 'unknown'], inplace=True) #reemplazo valores dudosos por 'unknow'

# %%
df['Fatal (Y/N)'].replace([' N','N ', 'y'], ['N', 'N', 'Y'], inplace=True) #reemplazo valores dudosos por 'unknow'

# %%
print(df['Fatal (Y/N)'].value_counts())
# Out:
# N          4301
# Y          1389
# unknown     612
# Name: Fatal (Y/N), dtype: int64

# %%
df.head()
# Out:
#   Case Number       Date  Year        Type    Country             Area  \
# 0        6302 2018-06-25  2018     Boating        USA       California
# 1        6301 2018-06-18  2018  Unprovoked        USA          Georgia
# 2        6300 2018-06-09  2018     Invalid        USA           Hawaii
# 3        6299 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4        6298 2018-06-04  2018    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex       Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F       57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F       11
# 2                    Habush, Oahu      Surfing      John Denges    M       48
# 3              Arrawarra Headland      Surfing             male    M  unknown
# 4                        La Ticla  Free diving   Gustavo Ramos     M  unknown
#
# ...

# %% [markdown]
# paso 9 Limpiar y unificar los tipos de accidente en la columna 'Type'

# %%
print(df['Type'].value_counts())
# Out:
# Unprovoked      4595
# Provoked         574
# Invalid          547
# Sea Disaster     239
# Boating          203
# Boat             137
# unknown            4
# Questionable       2
# Boatomg            1
# Name: Type, dtype: int64

# %%
df['Type'].replace(['Boat','Boatomg', 'Questionable', ], ['Boating', 'Boating', 'Invalid'], inplace=True) #reagrupo valores equivalentes

# %%
print(df['Type'].value_counts())
# Out:
# Unprovoked      4595
# Provoked         574
# Invalid          549
# Boating          341
# Sea Disaster     239
# unknown            4
# Name: Type, dtype: int64
