# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\cleme\laboratorios\PROYECTO-SHARKS-CARLOS\data\attacks.csv', encoding= "ISO-8859-1")

# %%
df.head(20)
# Out:
#      Case Number                  Date    Year          Type       Country  \
# 0     2018.06.25           25-Jun-2018  2018.0       Boating           USA
# 1     2018.06.18           18-Jun-2018  2018.0    Unprovoked           USA
# 2     2018.06.09           09-Jun-2018  2018.0       Invalid           USA
# 3     2018.06.08           08-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 4     2018.06.04           04-Jun-2018  2018.0      Provoked        MEXICO
# 5   2018.06.03.b           03-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 6   2018.06.03.a           03-Jun-2018  2018.0    Unprovoked        BRAZIL
# 7     2018.05.27           27-May-2018  2018.0    Unprovoked           USA
# 8   2018.05.26.b           26-May-2018  2018.0    Unprovoked           USA
# 9   2018.05.26.a           26-May-2018  2018.0    Unprovoked           USA
# 10    2018.05.24           24-May-2018  2018.0      Provoked     AUSTRALIA
# ...

# %%
df.shape
# Out:
# (25723, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %% [markdown]
#   1 Paso.- Consiste en filtrar todas las filas que contengan un número de celdas sin información en un número de 8 o másy eliminarlas considerando que la tabla tiene 23 cifras.

# %%
df = df[df.count(axis=1) >= 8]

# %%
df.shape
# Out:
# (6302, 24)

# %% [markdown]
# 2 Paso. Rellenar todas las celdas sin datos con 'unknow', considerando como 8 celdas en la fila la menor información posible para ser interpretable.

# %%
df = df.fillna('unknown')

# %%
df
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %% [markdown]
# 3 paso Elimino la fila de año para rellenarla con el índice de 1 a n registros, en definitiva se denomina "Case number". Ejecuto un bucle  que me cambia esta columna de forma inversa del 1 en la última posición hasta el primero en la posición 6302

# %%
n_fila = df.shape[0]

for i in range(n_fila):
    df.loc[i, 'Case Number'] = n_fila - i
    

df
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0           6302  25-Jun-2018  2018.0     Boating                 USA
# 1           6301  18-Jun-2018  2018.0  Unprovoked                 USA
# 2           6300  09-Jun-2018  2018.0     Invalid                 USA
# 3           6299  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4           6298  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297           5  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298           4  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299           3    1900-1905     0.0  Unprovoked                 USA
# 6300           2    1883-1889     0.0  Unprovoked              PANAMA
# 6301           1    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...
